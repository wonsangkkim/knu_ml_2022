# %% [markdown]
# <a href="https://colab.research.google.com/github/wonsangkkim/knu_bdna_2022/blob/main/%EA%B9%80%EC%83%81%EC%9B%906%EA%B0%957%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_train['Age'].isnull().sum()
# Out:
# 177

# %%
100*df_train['Age'].isnull().sum()/df_train[df_train.columns].shape[0]
# Out:
# 19.865319865319865

# %%
for col in df_train.columns:
  msg = '{:>10}:\t Percentage of NaN: {:.2f}%'.format(col, 100*(df_train[col].isnull().sum() /df_train[col].shape[0]))
  print(msg)
# Out:
# PassengerId:	 Percentage of NaN: 0.00%
#   Survived:	 Percentage of NaN: 0.00%
#     Pclass:	 Percentage of NaN: 0.00%
#       Name:	 Percentage of NaN: 0.00%
#        Sex:	 Percentage of NaN: 0.00%
#        Age:	 Percentage of NaN: 19.87%
#      SibSp:	 Percentage of NaN: 0.00%
#      Parch:	 Percentage of NaN: 0.00%
#     Ticket:	 Percentage of NaN: 0.00%
#       Fare:	 Percentage of NaN: 0.00%
#      Cabin:	 Percentage of NaN: 77.10%
#   Embarked:	 Percentage of NaN: 0.22%

# %%
import matplotlib.pyplot as plt
import missingno as msno
msno.matrix(df=df_train, figsize=(6,6))
plt.show()

# %%
msno.bar(df=df_train, figsize=(6,6))
plt.show()

# %%
df_train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df_train['Survived'].value_counts().plot.bar()

# %%
df_train['Survived'].value_counts().plot.pie(explode=[0,0.1])
plt.show()

# %%
sns.countplot(x='Survived',data=df_train)
plt.show()

# %%
df_train[['Pclass','Survived']]
# Out:
#      Pclass  Survived
# 0         3         0
# 1         1         1
# 2         3         1
# 3         1         1
# 4         3         0
# ..      ...       ...
# 886       2         0
# 887       1         1
# 888       3         0
# 889       1         1
# 890       3         0
#
# [891 rows x 2 columns]

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean().sort_values
# Out:
# <bound method DataFrame.sort_values of         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363>

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived')
# Out:
#         Survived
# Pclass
# 3       0.242363
# 2       0.472826
# 1       0.629630

# %%
df_train[['Pclass','Survived']].groupby(['Pclass']).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'],df_train['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(df_train['Pclass'],df_train['Survived'],margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
pd.crosstab(df_train['Pclass'],df_train['Survived'],margins=True).style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_9d7c0_row0_col0, #T_9d7c0_row1_col1, #T_9d7c0_row1_col2 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_9d7c0_row0_col1 {
#   background-color: #31ceff;
#   color: #000000;
# }
# #T_9d7c0_row0_col2 {
#   background-color: #0bf4ff;
#   color: #000000;
# }
# #T_9d7c0_row1_col0 {
#   background-color: #09f6ff;
#   color: #000000;
# }
# #T_9d7c0_row2_col0 {
#   background-color: #9f60ff;
#   color: #f1f1f1;
# }
# #T_9d7c0_row2_col1 {
#   background-color: #20dfff;
#   color: #000000;
# }
# #T_9d7c0_row2_col2 {
#   background-color: #6f90ff;
#   color: #f1f1f1;
# }
# #T_9d7c0_row3_col0, #T_9d7c0_row3_col1, #T_9d7c0_row3_col2 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9d7c0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d7c0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9d7c0_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_9d7c0_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_9d7c0_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_9d7c0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9d7c0_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_9d7c0_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_9d7c0_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_9d7c0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9d7c0_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_9d7c0_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_9d7c0_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_9d7c0_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_9d7c0_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_9d7c0_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_9d7c0_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived',ascending=False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived',ascending=False).plot()

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived',ascending=False).plot.bar()
plt.show()

# %%
df_train['Pclass'].value_counts().plot.bar()
plt.show()

# %%
sns.countplot(x='Pclass',hue='Survived',data=df_train)
plt.show()

# %%
sns.set(font_scale=2.5)
f,ax=plt.subplots(1,2,figsize=(16,8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
sns.countplot(x='Pclass',hue='Survived',data=df_train, ax=ax[1])
plt.show()

# %%
sns.set(font_scale=2.5)
f,ax=plt.subplots(1,2,figsize=(16,8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
sns.countplot(x='Pclass',hue='Survived',data=df_train, ax=ax[1])
ax[1].set_title('Number of survived vs dead')
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import numpy as np
x = np.random.rand(100)
eps = np.random.rand(100)/1.5
y =3*x+1+eps
plt.plot(x,y,'.')
plt.show()

# %%
a=0
b=0
alpha=0.01
n=100
err_evolve=[]
it_index=[]
for it in range(2000):
  
  delta_a=0
  delta_b=0
  err=0
  for i in range(n):
    delta_a=delta_a+2*(a*x[i]+b-y[i])+x[i]
    delta_b=delta_b+2*(a*x[i]+b-y[i])
    err=err+(a*x[i]+b-y[i])*(a*x[i]+b-y[i])/n
  a=a-alpha*delta_a/n
  b=b-alpha*delta_b/n
  err_evolve.append(err)
  it_index.append(it)
  if it%200==0:
    plt.plot(x,y,'.',x,a*x+b)
    plt.legend(labels=('Sample Data','Linear Regression'))
    plt.title('iteration %d' %it)
    plt.show()

# %%
a
# Out:
# array([16.23858939])

# %%
b
# Out:
# array([19.23563409])

# %%
print(err)
# Out:
# 5.550740584756261

# %%
plt.plot(it_index,err_evolve)
plt.title('Change of MSE')
plt.show()

# %%
from sklearn.datasets import make_regression
x,y,coeff = make_regression(n_samples=200, n_features=1, bias=10, noise=50,coef=True, random_state=1)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'k.')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)
model = model.fit(x,y)

# %%
model.coef_
# Out:
# array([89.01678804])

# %%
model.intercept_
# Out:
# 8.95754344934731

# %%
y_pred = model.predict(x)
plt.plot(x,y,',',x,y_pred)
# Out:
# [<matplotlib.lines.Line2D at 0x7fcd6b11cb10>,
#  <matplotlib.lines.Line2D at 0x7fcd6b11c090>]
