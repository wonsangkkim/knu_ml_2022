# %% [markdown]
# <a href="https://colab.research.google.com/github/wonsangkkim/knu_ml_2022/blob/main/%EA%B9%80%EC%83%81%EC%9B%905%EA%B0%956%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {'age':[23,43,12,45],'names':['민준','현우','서연','동현'],'height':[175.3,180.3,165.8,172.7]}
x = pd.DataFrame(data,columns=['names','age','height'])
x
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7

# %%
x.loc[4]=['광현',32,176]
x.loc[5]=['현아',23,158]
x
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0

# %%
y=pd.DataFrame({'age':[33],'names':['철수'],'height':180.},columns=['age','names','height'])
y
# Out:
#    age names  height
# 0   33    철수   180.0

# %%
result=x.append(y)

# %%
result
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 0    철수   33   180.0

# %%
result=x.append(y, ignore_index=True)
result
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 6    철수   33   180.0

# %%
x=x.append(y, ignore_index=True)
x
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 6    철수   33   180.0

# %%
result = pd.concat([x,y], ignore_index=True )
result
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 6    철수   33   180.0
# 7    철수   33   180.0

# %%
import numpy as np

# %%
df = pd.DataFrame ( np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1] = np.nan
df.iloc[2,2] = np.nan
df
# Out:
#           A         B         C         D         E
# 0 -0.396249  0.284771 -1.594673  0.030483 -0.438852
# 1 -2.943328       NaN -0.543808  1.237085  2.163941
# 2 -0.007802  0.864984       NaN -1.767078 -0.491670
# 3  0.778870  0.176009  0.458935  1.429458 -0.170960
# 4  1.292370  0.321560 -0.246408  0.770530 -1.492116

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False   True  False  False  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
df['A'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df['C'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: C, dtype: bool

# %%
df['D'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: D, dtype: bool

# %%
df['E'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: E, dtype: bool

# %%
df[df['B'].isnull()]
# Out:
#           A   B         C         D         E
# 1 -2.943328 NaN -0.543808  1.237085  2.163941

# %%
df[df['C'].isnull()]
# Out:
#           A         B   C         D        E
# 2 -0.007802  0.864984 NaN -1.767078 -0.49167

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    0
# E    0
# dtype: int64

# %%
df['A'].isnull().sum()
# Out:
# 0

# %%
df['B'].isnull().sum()
# Out:
# 1

# %%
df['C'].isnull().sum()
# Out:
# 1

# %%
df['D'].isnull().sum()
# Out:
# 0

# %%
df['E'].isnull().sum()
# Out:
# 0

# %%
df = pd.DataFrame ( np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1] = np.nan
df.iloc[2,2] = np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.173314  0.339114 -0.091578 -0.047512  1.535685
# 1 -0.301828       NaN  0.203046 -1.150550  0.206582
# 2  0.794849 -1.578258       NaN  0.990279 -0.359479
# 3 -2.173088  1.313376 -0.931694 -2.678600  0.087751
# 4 -0.096836  1.591599 -0.591707  0.321276  1.575001

# %%
df.dropna(subset=['B'], axis=0, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  0.173314  0.339114 -0.091578 -0.047512  1.535685
# 2  0.794849 -1.578258       NaN  0.990279 -0.359479
# 3 -2.173088  1.313376 -0.931694 -2.678600  0.087751
# 4 -0.096836  1.591599 -0.591707  0.321276  1.575001

# %%
df = pd.DataFrame ( np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1] = np.nan
df.iloc[2,2] = np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.372020  1.003724  0.323831  0.716856 -0.408132
# 1 -0.187828       NaN  0.218378 -0.772296 -0.002878
# 2  1.593021  1.176399       NaN -0.096662 -0.553243
# 3  1.251889  0.778839 -0.461265 -0.384517 -0.263976
# 4  1.587117  0.914177 -0.414476 -0.642209  0.749156

# %%
df.dropna( axis=1, inplace=True)
df
# Out:
#           A         D         E
# 0  0.372020  0.716856 -0.408132
# 1 -0.187828 -0.772296 -0.002878
# 2  1.593021 -0.096662 -0.553243
# 3  1.251889 -0.384517 -0.263976
# 4  1.587117 -0.642209  0.749156

# %%
df.dropna(subset=[0,1],axis=1, inplace=True)
df
# Out:
#           A         D         E
# 0  0.372020  0.716856 -0.408132
# 1 -0.187828 -0.772296 -0.002878
# 2  1.593021 -0.096662 -0.553243
# 3  1.251889 -0.384517 -0.263976
# 4  1.587117 -0.642209  0.749156

# %%
robots = [[24, 23680],[35,np.nan],[46,47350],[27,np.nan]]
data = pd.DataFrame(robots, columns=['max_spped','price'])
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
data.replace(np.nan,0,inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan,mean,inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan,mean)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt

# %%
vais = iris['sepal_length'].values
sns.kdeplot(vais)
plt.title("kdeplot for sepal lenght")
plt.show()

# %%
vais = iris['petal_length'].values
sns.kdeplot(vais)
plt.title("kdeplot for petal lenght")
plt.show()

# %%
vais = iris['petal_length'].values
sns.displot(vais,kde=True, rug=True)
plt.title("kdeplot for petal lenght")
plt.show()

# %%
vais = iris['petal_length'].values
sns.kdeplot(vais)
sns.displot(vais,kde=True, rug=True)
plt.title("kdeplot for petal lenght")
plt.show()

# %%
sns.histplot(vais, kde=True)
plt.title("histplot for petal lenght")
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="adult_male",data=titanic)
plt.show()

# %%
titanic.adult_male
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: adult_male, Length: 891, dtype: bool

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x="day", data=tips)
plt.show()

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind='scatter')
plt.show()

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, hue='species', kind='kde')
plt.show()

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue='species', markers=['o','s','d'])
plt.show()

# %%
titanic_size= titanic.pivot_table(index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, annot=True)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, annot=True, fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, cmap=sns.color_palette("PuBu") , annot=True, fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.barplot(y="day", x="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
plt.title("Tips on each day")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=False)
plt.title("Tips on each day")
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue='time', data=tips)
plt.title("Tips on each day with hue=time")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", hue='sex', data=tips, split=True)
plt.title("Tips on each day with hue=sex and split=True")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", hue='sex', data=tips, dodge=True)
plt.title("Tips on each day with hue=sex and dodge=True")
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue='sex', data=tips, dodge=True)
plt.title("Tips on each day with hue=sex and dodge=True")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="age",y="sex", hue="survived", row="class", data=titanic, kind="violin", split=True, height=2, aspect=4)
plt.title("Catplot of titanic with hue=survived")
plt.show()

# %%
plt.title("violinplot and swarmplot")
sns.violinplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color='0.9')
plt.show()

# %%
##############################

# %%
##############################

# %%
import pandas as pd
df_train=pd.read_csv('train.csv', encoding='CP949')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd
df_test=pd.read_csv('test.csv', encoding='CP949')

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_train['Age'].isnull().sum()
# Out:
# 177

# %%
100*df_train['Age'].isnull().sum()/df_train[df_train.columns].shape[0]
# Out:
# 19.865319865319865

# %%
for col in df_train.columns:
  msg='{:>10}:\t Percentage of NaN: {:.2f}%'.format(col, 100*(df_train[col].isnull().sum() / df_train[col].shape[0]))
  print(msg)
# Out:
# PassengerId:	 Percentage of NaN: 0.00%
#   Survived:	 Percentage of NaN: 0.00%
#     Pclass:	 Percentage of NaN: 0.00%
#       Name:	 Percentage of NaN: 0.00%
#        Sex:	 Percentage of NaN: 0.00%
#        Age:	 Percentage of NaN: 19.87%
#      SibSp:	 Percentage of NaN: 0.00%
#      Parch:	 Percentage of NaN: 0.00%
#     Ticket:	 Percentage of NaN: 0.00%
#       Fare:	 Percentage of NaN: 0.00%
#      Cabin:	 Percentage of NaN: 77.10%
#   Embarked:	 Percentage of NaN: 0.22%

# %%
for col in df_test.columns:
  msg='{:>10}:\t Percentage of NaN: {:.2f}%'.format(col, 100*(df_test[col].isnull().sum() / df_test[col].shape[0]))
  print(msg)
# Out:
# PassengerId:	 Percentage of NaN: 0.00%
#     Pclass:	 Percentage of NaN: 0.00%
#       Name:	 Percentage of NaN: 0.00%
#        Sex:	 Percentage of NaN: 0.00%
#        Age:	 Percentage of NaN: 20.57%
#      SibSp:	 Percentage of NaN: 0.00%
#      Parch:	 Percentage of NaN: 0.00%
#     Ticket:	 Percentage of NaN: 0.00%
#       Fare:	 Percentage of NaN: 0.24%
#      Cabin:	 Percentage of NaN: 78.23%
#   Embarked:	 Percentage of NaN: 0.00%

# %%
import missingno as msno
import matplotlib.pyplot as plt
msno.matrix(df=df_train, figsize=(6,6))
plt.show()

# %%
msno.bar(df=df_train, figsize=(6,6))
plt.show()

# %%
df_train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df_train['Survived'].value_counts().plot.bar()

# %%
df_train['Survived'].value_counts().plot.pie(explode=[0,0.1])
plt.show()

# %%
sns.countplot(x='Survived', data=df_train)
plt.show()

# %%
df_train[['Pclass', 'Survived']]
# Out:
#      Pclass  Survived
# 0         3         0
# 1         1         1
# 2         3         1
# 3         1         1
# 4         3         0
# ..      ...       ...
# 886       2         0
# 887       1         1
# 888       3         0
# 889       1         1
# 890       3         0
#
# [891 rows x 2 columns]

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values
# Out:
# <bound method DataFrame.sort_values of         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived')
# Out:
#         Survived
# Pclass
# 3       0.242363
# 2       0.472826
# 1       0.629630

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass']).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_a2827_row0_col0, #T_a2827_row1_col1, #T_a2827_row1_col2 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_a2827_row0_col1 {
#   background-color: #31ceff;
#   color: #000000;
# }
# #T_a2827_row0_col2 {
#   background-color: #0bf4ff;
#   color: #000000;
# }
# #T_a2827_row1_col0 {
#   background-color: #09f6ff;
#   color: #000000;
# }
# #T_a2827_row2_col0 {
#   background-color: #9f60ff;
#   color: #f1f1f1;
# }
# #T_a2827_row2_col1 {
#   background-color: #20dfff;
#   color: #000000;
# }
# #T_a2827_row2_col2 {
#   background-color: #6f90ff;
#   color: #f1f1f1;
# }
# #T_a2827_row3_col0, #T_a2827_row3_col1, #T_a2827_row3_col2 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2827_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2827_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a2827_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_a2827_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_a2827_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_a2827_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a2827_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_a2827_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_a2827_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_a2827_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a2827_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_a2827_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_a2827_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_a2827_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_a2827_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_a2827_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_a2827_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived', ascending=False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived', ascending=False).plot()

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
plt.show()

# %%
df_train['Pclass'].value_counts().plot.bar()
plt.show()

# %%
sns.countplot(x='Pclass',hue='Survived', data=df_train)
plt.show()

# %%
sns.set(font_scale=2.5)

# %%
f, ax= plt.subplots(1,2, figsize=(16,8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
sns.countplot(x='Pclass', hue='Survived', data=df_train, ax=ax[1])
plt.show()

# %%
f, ax= plt.subplots(1,2, figsize=(16,8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of Passengers')
sns.countplot(x='Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Number of survived vs dead')
plt.show()
