# %% [markdown]
# <a href="https://colab.research.google.com/github/wonsangkkim/knu_bdna_2022/blob/main/%EA%B9%80%EC%83%81%EC%9B%90_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {'age':[23,43,12,45],'names':['민준','현우','서연','동현'],'height':[175.3,180.3,165.8,172.7]}
x = pd.DataFrame(data,columns=['names','age','height'])
x
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7

# %%
x.loc[4]=['광현',32,176]
x.loc[5]=['현아',23,158]
x
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0

# %%
y=pd.DataFrame({'age':[33],'names':['철수'],'height':180.},columns=['age','names','height'])
y
# Out:
#    age names  height
# 0   33    철수   180.0

# %%
result=x.append(y)

# %%
result
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 0    철수   33   180.0

# %%
result=x.append(y, ignore_index=True)
result
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 6    철수   33   180.0

# %%
x=x.append(y, ignore_index=True)
x
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 6    철수   33   180.0

# %%
result = pd.concat([x,y], ignore_index=True )
result
# Out:
#   names  age  height
# 0    민준   23   175.3
# 1    현우   43   180.3
# 2    서연   12   165.8
# 3    동현   45   172.7
# 4    광현   32   176.0
# 5    현아   23   158.0
# 6    철수   33   180.0
# 7    철수   33   180.0

# %%
import numpy as np

# %%
df = pd.DataFrame ( np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1] = np.nan
df.iloc[2,2] = np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.701586  1.703877 -0.241889 -0.271070 -0.348506
# 1  0.869280       NaN  0.188508  0.930737 -1.257305
# 2 -0.689992  0.109893       NaN -1.446471 -1.958649
# 3  0.277795  1.745602 -0.069001 -0.018597  0.788831
# 4 -0.289384  0.739318 -0.863206 -0.641544  0.717818

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False   True  False  False  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
df['A'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df['C'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: C, dtype: bool

# %%
df['D'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: D, dtype: bool

# %%
df['E'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: E, dtype: bool

# %%
df[df['B'].isnull()]
# Out:
#          A   B         C         D         E
# 1  0.86928 NaN  0.188508  0.930737 -1.257305

# %%
df[df['C'].isnull()]
# Out:
#           A         B   C         D         E
# 2 -0.689992  0.109893 NaN -1.446471 -1.958649

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    0
# E    0
# dtype: int64

# %%
df['A'].isnull().sum()
# Out:
# 0

# %%
df['B'].isnull().sum()
# Out:
# 1

# %%
df['C'].isnull().sum()
# Out:
# 1

# %%
df['D'].isnull().sum()
# Out:
# 0

# %%
df['E'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.701586  1.703877 -0.241889 -0.271070 -0.348506
# 1  0.869280       NaN  0.188508  0.930737 -1.257305
# 2 -0.689992  0.109893       NaN -1.446471 -1.958649
# 3  0.277795  1.745602 -0.069001 -0.018597  0.788831
# 4 -0.289384  0.739318 -0.863206 -0.641544  0.717818

# %%
df.dropna()
# Out:
#           A         B         C         D         E
# 0  0.701586  1.703877 -0.241889 -0.271070 -0.348506
# 3  0.277795  1.745602 -0.069001 -0.018597  0.788831
# 4 -0.289384  0.739318 -0.863206 -0.641544  0.717818

# %%
df.dropna(inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  0.701586  1.703877 -0.241889 -0.271070 -0.348506
# 3  0.277795  1.745602 -0.069001 -0.018597  0.788831
# 4 -0.289384  0.739318 -0.863206 -0.641544  0.717818

# %%
df = pd.DataFrame ( np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1] = np.nan
df.iloc[2,2] = np.nan
df
# Out:
#           A         B         C         D         E
# 0 -0.415162 -0.159288  1.981074  0.534419 -0.369636
# 1  0.008320       NaN  0.179450  1.948838 -0.879349
# 2 -0.189101  0.536895       NaN  0.858171 -1.421842
# 3 -0.068806  1.045634 -0.089747 -0.898416  0.371909
# 4  0.001566  0.008566 -0.286165  0.368651 -1.549236

# %%
df.dropna(subset=['B'], axis=0, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0 -0.415162 -0.159288  1.981074  0.534419 -0.369636
# 2 -0.189101  0.536895       NaN  0.858171 -1.421842
# 3 -0.068806  1.045634 -0.089747 -0.898416  0.371909
# 4  0.001566  0.008566 -0.286165  0.368651 -1.549236

# %%
df = pd.DataFrame ( np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1] = np.nan
df.iloc[2,2] = np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.014759  0.879826  0.698395  2.112688  0.702261
# 1 -1.248765       NaN  0.052643  0.971929 -0.006975
# 2  1.850973  0.573308       NaN -1.187633 -2.498012
# 3 -1.136526  0.306723  1.824692 -0.467417  0.287923
# 4  1.952322 -2.236244  0.072075  0.605677 -1.180475

# %%
df.dropna( axis=1, inplace=True)
df
# Out:
#           A         D         E
# 0  0.014759  2.112688  0.702261
# 1 -1.248765  0.971929 -0.006975
# 2  1.850973 -1.187633 -2.498012
# 3 -1.136526 -0.467417  0.287923
# 4  1.952322  0.605677 -1.180475

# %%
df.dropna(subset=[0,1],axis=1, inplace=True)
df
# Out:
#           A         D         E
# 0  0.014759  2.112688  0.702261
# 1 -1.248765  0.971929 -0.006975
# 2  1.850973 -1.187633 -2.498012
# 3 -1.136526 -0.467417  0.287923
# 4  1.952322  0.605677 -1.180475

# %%
robots = [[24, 23680],[35,np.nan],[46,47350],[27,np.nan]]
data = pd.DataFrame(robots, columns=['max_spped','price'])
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
data.replace(np.nan,0,inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan,mean,inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan,mean)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt

# %%
vais = iris['sepal_length'].values
sns.kdeplot(vais)
plt.title("kdeplot for sepal lenght")
plt.show()

# %%
vais = iris['petal_length'].values
sns.kdeplot(vais)
plt.title("kdeplot for petal lenght")
plt.show()

# %%
vais = iris['petal_length'].values
sns.displot(vais,kde=True, rug=True)
plt.title("kdeplot for petal lenght")
plt.show()

# %%
vais = iris['petal_length'].values
sns.kdeplot(vais)
sns.displot(vais,kde=True, rug=True)
plt.title("kdeplot for petal lenght")
plt.show()

# %%
sns.histplot(vais, kde=True)
plt.title("histplot for petal lenght")
plt.show()

# %% [markdown]
# 8주차 강의 끝

# %% [markdown]
# 9주차 강의 시작

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="adult_male",data=titanic)
plt.show()

# %%
titanic.adult_male
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: adult_male, Length: 891, dtype: bool

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x="day", data=tips)
plt.show()

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind='scatter')
plt.show()

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, hue='species', kind='kde')
plt.show()

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue='species', markers=['o','s','d'])
plt.show()

# %%
titanic_size= titanic.pivot_table(index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, annot=True)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, annot=True, fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, cmap=sns.color_palette("PuBu") , annot=True, fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.barplot(y="day", x="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
plt.title("Tips on each day")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=False)
plt.title("Tips on each day")
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue='time', data=tips)
plt.title("Tips on each day with hue=time")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("Tips on each day with hue=sex")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", hue='sex', data=tips, split=True)
plt.title("Tips on each day with hue=sex and split=True")
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", hue='sex', data=tips, dodge=True)
plt.title("Tips on each day with hue=sex and dodge=True")
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue='sex', data=tips, dodge=True)
plt.title("Tips on each day with hue=sex and dodge=True")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="age",y="sex", hue="survived", row="class", data=titanic, kind="violin", split=True, height=2, aspect=4)
plt.title("Catplot of titanic with hue=survived")
plt.show()

# %%
plt.title("violinplot and swarmplot")
sns.violinplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color='0.9')
plt.show()
